# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot () #Tạo Chart
# Out:
# []

# %%
plt.plot();

# %%
x = [1,2,3,4]
y = [10,8,6,9]

# %%
plt.plot(x,y,color = 'red');

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# # Pyplot API and Object-Oriented (OO) API
# * Pylot API => Quickly
# * OO API => Advance

# %% [markdown]
# ### Pyplot API

# %%
x = np.linspace(0,10,1000)

# %%
plt.plot(x,np.sin(x),color = 'pink',label = "sin(x)",linestyle = "dashed");
plt.plot(x,np.cos(x),color = 'blue',label = "cos(x)");
plt.title('Sin(x) and Cos(x)');
plt.xlabel('Bien X')
plt.ylabel('Sin(X)')
#plt.xlim([0,4]) #Gioi han do thi tu 0 den 4
#plt.ylim([-0.7,0,6 ])
#plt.axis([0,4,-0.7,0.6]) #Gioi han do thi theo truc tung(x) va truc hoanh(y)
plt.axis('equal') 
plt.legend();

# %% [markdown]
# ### Object-Oriented (OO) API

# %%
#1 Prepare Data
x = [1,2,3,4]
y= [11,22,33,44]
#2 Set up plot
fig,ax = plt.subplots(figsize=(5,5)) #Size 5x5 #Fig la hinh tong con ax la hinh nho
#3. Plot the data
ax.plot(x,y);
ax.set(title = 'Simple plot',xlabel = 'Truc X',ylabel = 'Truc Y');

# %% [markdown]
# # 2.Most common type of Matplotib plots
# * Line
# * Scatter
# * Bar
# * Hist
# * Suplots()
# ### Line

# %%
# Create array 
x = np.linspace(0,10,100) #Tu 0 den 10 va data la 100 
x[:5]
# Out:
# array([0.       , 0.1010101, 0.2020202, 0.3030303, 0.4040404])

# %%
## OO API plot a line chart 
fig,ax = plt.subplots()
ax.plot(x,x**3);

# %% [markdown]
# ### Scatter

# %%
# Pylot API 
plt.scatter(x,np.exp(x)); #no.exp(x) = e^(x)

# %%
## OO API 
# Prepare Data 
rng = np.random.RandomState(0)
x = rng.rand(100)
y = rng.rand(100)
size = 1000*rng.rand(100) 
colors = rng.rand(100)
fig,ax = plt.subplots()
im1 = ax.scatter(x,y,s = size,c = colors,cmap = 'viridis',alpha = 0.3); #Alpha la do trong suot,cmap la chinh bang mau
fig.colorbar(im1);

# %% [markdown]
# ### Bar
# * Vertical
# * Horizontal

# %%
# Vertical
#Prepare Data
soft_drinks = {"Coke":12,
               "Pepsi":10,
               "7 up": 8}

# %%
fig,ax = plt.subplots()
ax.bar(soft_drinks.keys(),soft_drinks.values());
ax.set(title = "Bach Hoa Xanh",ylabel = 'Price ($)');

# %% [markdown]
# fig,ax = plt.subplots()
# ax.barh(list(soft_drinks.keys()),list(soft_drinks.values()));

# %% [markdown]
# ### Histogram

# %%
np.random.seed(42)
student_height = np.random.normal(170,10,250)
student_height[:10], len(student_height)
# Out:
# (array([174.96714153, 168.61735699, 176.47688538, 185.23029856,
#         167.65846625, 167.65863043, 185.79212816, 177.67434729,
#         165.30525614, 175.42560044]),
#  250)

# %%
#Pyplot API 
plt.hist(student_height,color = "pink",bins = 30);

# %% [markdown]
# # Subplots

# %%
# Option 1:
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
#Plot data
ax1.plot(x,x/2);
ax1.plot(x,x*2);
ax2.scatter(np.random.random(100),np.random.random(100),cmap = 'viridis',alpha = 0.3);
ax3.bar(soft_drinks.keys(),soft_drinks.values(),color = 'blue');
ax4.hist(student_height,color = 'blue');

# %%
# Option 2:
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
#Plot data
ax[0,0].plot(x,x/2);
ax[0,0].plot(x,x*2);
ax[0,1].scatter(np.random.random(100),np.random.random(100),cmap = 'viridis',alpha = 0.3);
ax[1,0].bar(soft_drinks.keys(),soft_drinks.values(),color = 'blue');
ax[1,1].hist(student_height,color = 'blue');

# %% [markdown]
# # Project State California

# %%
cities = pd.read_csv('./california_cities.csv')

# %%
cities.head()
#Find a Data Area (Before)
cities['area_total_km2'].sort_values(ascending= False)
# Out:
# 239    1302.000
# 367     964.510
# 55      527.401
# 375     466.109
# 26      371.946
#          ...
# 163         NaN
# 237         NaN
# 370         NaN
# 393         NaN
# 443         NaN
# Name: area_total_km2, Length: 482, dtype: float64

# %%
latitude,longitude = cities['latd'],cities['longd']
#Import more data
population, area = cities['population_total'],cities['area_total_km2']
latitude[:10],longitude[:10]
# Out:
# (0    34.576111
#  1    34.153333
#  2    37.756111
#  3    37.886944
#  4    34.081944
#  5    33.575000
#  6    41.487222
#  7    38.419444
#  8    38.168056
#  9    33.836111
#  Name: latd, dtype: float64,
#  0   -117.432778
#  1   -118.761667
#  2   -122.274444
#  3   -122.297778
#  4   -118.135000
#  5   -117.725556
#  6   -120.542500
#  7   -120.824167
#  8   -122.252500
#  9   -117.889722
#  Name: longd, dtype: float64)

# %%
# Pyplot API 
plt.style.use('seaborn')
plt.scatter(longitude,latitude,c= np.log10(population),cmap = 'viridis',
            s = area,linewidths=0,alpha = 0.5);
plt.axis('equal');
plt.xlabel('longitude');
plt.ylabel('latitude');
plt.colorbar(label = 'log$_(10)$(population)');
plt.clim(3,7)
plt.title('California Cities: Population and Area Distribution');
# Create A legend Size 
area_range = [50,100,300,500]
for area in area_range:
    plt.scatter([],[],s=area,c ='k',alpha = 0.5,label= str(area) + 'km$^2$')
plt.legend(labelspacing=1,title = 'City Area');
